# %%
# !pip install pdfplumber
# Out:
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.9-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 2.5 MB/s eta 0:00:00
# Collecting pdfminer.six==20251230 (from pdfplumber)
#   Downloading pdfminer_six-20251230-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.12/dist-packages (from pdfplumber) (11.3.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-5.3.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251230->pdfplumber) (3.4.4)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251230->pdfplumber) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (3.0)
# Downloading pdfplumber-0.11.9-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.8 MB/s eta 0:00:00
# Downloading pdfminer_six-20251230-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 76.6 MB/s eta 0:00:00
# Downloading pypdfium2-5.3.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 81.8 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20251230 pdfplumber-0.11.9 pypdfium2-5.3.0

# %%
import os
import re
import math
import time
import numpy as np
import pandas as pd
import pdfplumber
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer, LAParams
import json
from google import genai
from google.genai import types
from google.colab import drive
from google.colab import userdata
userdata.get('GEMINI_API_KEY')
drive.mount('/content/drive')

INPUT_DIR = "/content/drive/MyDrive/annual_reports"
OUTPUT_DIR = "extracted_letters"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
d_companies = {
    "Tesla": {"ticker": "TSLA", "exchange": "NASDAQ", "country": "US"},
    "BMW": {"ticker": "BMW.DE", "exchange": "Xetra", "country": "EU"},
    "Volkswagen": {"ticker": "VOW3.DE", "exchange": "Xetra", "country": "EU"},
    "Benz": {"ticker": "MBG.DE", "exchange": "Xetra", "country": "EU"},
    "Toyota": {"ticker": "7203.T", "exchange": "Tokyo", "country": "JP"},
    "Stellantis": {"ticker": "STLA", "exchange": "NYSE", "country": "EU"},
    "Bosch": {"ticker": "BOS.IN", "exchange": "IN", "country": "IN"},
    "Apple": {"ticker": "AAPL", "exchange": "NASDAQ", "country": "US"},
    "Microsoft": {"ticker": "MSFT", "exchange": "NASDAQ", "country": "US"},
    "Intel": {"ticker": "INTC", "exchange": "NASDAQ", "country": "US"},
    "Qualcomm": {"ticker": "QCOM", "exchange": "NASDAQ", "country": "US"},
    "Nvdia": {"ticker": "NVDA", "exchange": "NASDAQ", "country": "US"},
    "SAP": {"ticker": "SAP", "exchange": "NYSE / Xetra", "country": "EU"},
    "IBM": {"ticker": "IBM", "exchange": "NYSE", "country": "US"},
    "Jpmorgan": {"ticker": "JPM", "exchange": "NYSE", "country": "US"},
    "Goldman": {"ticker": "GS", "exchange": "NYSE", "country": "US"},
    "HSBC": {"ticker": "HSBC", "exchange": "NYSE", "country": "EU"},
    "Blackrock": {"ticker": "BLK", "exchange": "NYSE", "country": "US"},
    "Citigroup": {"ticker": "C", "exchange": "NYSE", "country": "US"},
    "Pfizer": {"ticker": "PFE", "exchange": "NYSE", "country": "US"},
    "J&J": {"ticker": "JNJ", "exchange": "NYSE", "country": "US"},
    "Nestle": {"ticker": "NESN.SW", "exchange": "Swiss", "country": "EU"},
    "Loreal": {"ticker": "OR.PA", "exchange": "Paris", "country": "EU"},
    "Shiseido": {"ticker": "4911.T", "exchange": "Tokyo", "country": "JP"},
    "P&G": {"ticker": "PG", "exchange": "NYSE", "country": "US"}
}

def get_slug(name, data):
    if name == "Bosch": return None
    # Manual Overrides
    if name == "BMW": return "OTC_BAMGF"
    if name == "Volkswagen": return "OTC_VWAGY"
    if name == "Benz": return "OTC_MBGAF"
    if name == "Nestle": return "OTC_NSRGY"
    if name == "Toyota": return "NYSE_TM"
    if name == "Loreal": return "Loreal_SA"
    if name == "Shiseido": return "Shiseido_Company_Limited"

    # Standard "EXCHANGE_TICKER" logic
    exchange = data['exchange']
    ticker = data['ticker']
    if "NYSE" in exchange: return f"NYSE_{ticker}"
    if "NASDAQ" in exchange: return f"NASDAQ_{ticker}"
    return None

# %%
START_PATTERNS = [
    r"to\s+our\s+shareholders",
    r"dear\s+shareholders",
    r"letter\s+from\s+the",
    r"message\s+from",
    r"executive\s+statement",
    r"chairman['’]s\s+statement",
    r"chief\s+executive['’]s\s+review",
    r"my\s+fellow\s+shareholders",
    r"letter\s+from\s+your\s+ceo",
    r"letter\s+from\s+your\s+chairman",
    r"dear\s+fellow\s+shareholders",
    r"dear\s+fellow",
    r"dear\s+shareowners",
    r"dear\s+stakeholders",
    r"dear\s+stakeholder",
    r"dear\s+nvidians"
]

STOP_PATTERNS = [
    r"sincerely",
    r"yours\s+truly",
    r"financial\s+review",        # Often the next section
    r"management['’]s\s+discussion", # MD&A section often follows
    r"consolidated\s+financial"   # Financial tables often follow
]

def extract_letter_from_pdf(pdf_path):
    extracted_text = ""
    start_found = False

    # We still use a max limit to prevent grabbing the whole book if we miss the stop signal
    max_pages_limit = 10
    pages_grabbed = 0

    # LAParams(detect_vertical=True) helps to detect text columns
    laparams = LAParams()

    try:
        # extract_pages performs layout analysis to group text into columns/boxes
        # We limit to first 20 pages using page_numbers
        page_iter = extract_pages(pdf_path, page_numbers=range(20), laparams=laparams)

        for i, page_layout in enumerate(page_iter):
            text = ""
            # iterate through layout elements (text boxes, figures, etc.)
            for element in page_layout:
                if isinstance(element, LTTextContainer):
                    text += element.get_text()

            if not text: continue

            clean_text = text.lower()

            # 1. SEARCH FOR START
            if not start_found:
                # Split page into lines to avoid matching Table of Contents entries (e.g., "Letter ... 5")
                lines = clean_text.split('\n')
                for j, line in enumerate(lines):
                    for pattern in START_PATTERNS:
                        if re.search(pattern, line):
                            # Check 1: Line itself ends in a small number (TOC entry)
                            toc_match = re.search(r'(\d+)\s*$', line.strip())
                            if toc_match:
                                number = int(toc_match.group(1))
                                if number < 1900: # Avoid skipping headers with years like "Review 2023"
                                    print(f"  [SKIP] Ignoring TOC-like line '{line.strip()}' on page {i+1}")
                                    continue

                            # Check 2: Next couple of lines START with page numbers (Multi-line TOC)
                            # e.g. "Letter to Shareholders" \n "5 ..." or "5 Overview"
                            is_multiline_toc = False
                            for offset in range(1, 5): # Look ahead 4 lines
                                if j + offset < len(lines):
                                    next_line_check = lines[j+offset].strip()

                                    # Check for number at start of line (possibly preceded by dots/spaces)
                                    # or "page X"
                                    match_start = re.match(r'^[\.\s]*(\d+)', next_line_check)
                                    match_page = re.match(r'^page\s+(\d+)', next_line_check)

                                    found_num = None
                                    if match_start:
                                        found_num = int(match_start.group(1))
                                    elif match_page:
                                        found_num = int(match_page.group(1))

                                    if found_num is not None and found_num < 1900:
                                         # FIX: Ignore if the line looks like a percentage (e.g. "61 percent...")
                                         if "percent" in next_line_check.lower() or "%" in next_line_check:
                                             continue

                                         print(f"  [SKIP] Ignoring TOC-like header '{line.strip()}' followed by TOC-like line '{next_line_check}' on page {i+1}")
                                         is_multiline_toc = True
                                         break

                            if is_multiline_toc:
                                continue

                            # Check 3: Line starts with a small number (TOC entry with leading page num)
                            # e.g. "5 ... Letter to Shareholders"
                            start_num_match = re.match(r'^\s*(\d+)', line.strip())
                            if start_num_match:
                                number = int(start_num_match.group(1))
                                if number < 1900:
                                    print(f"  [SKIP] Ignoring TOC-like line (leading num) '{line.strip()}' on page {i+1}")
                                    continue

                            # Check 4: Previous line is just a page number (Multi-line TOC with leading page num)
                            # e.g. "5" \n "Letter to Shareholders"
                            if j > 0:
                                prev_line = lines[j-1].strip()
                                if re.match(r'^[\.\s]*\d+$', prev_line) or re.match(r'^page\s+\d+$', prev_line):
                                     num_groups = re.findall(r'\d+', prev_line)
                                     if num_groups and int(num_groups[-1]) < 1900:
                                         print(f"  [SKIP] Ignoring TOC-like header '{line.strip()}' preceded by '{prev_line}' on page {i+1}")
                                         continue

                            print(f"  [START] Found start signature '{pattern}' on page {i+1}")
                            start_found = True
                            break
                    if start_found: break

            # 2. EXTRACT & SEARCH FOR STOP
            if start_found:
                extracted_text += f"\n--- Page {i+1} ---\n"
                extracted_text += text
                pages_grabbed += 1

                # Check for STOP signals in this page
                for stop_pat in STOP_PATTERNS:
                    if re.search(stop_pat, clean_text):
                        print(f"  [STOP] Found end signature '{stop_pat}' on page {i+1}")
                        return extracted_text # <--- STOP HERE IMMEDIATELY

                # Emergency Brake: If we grabbed too many pages, stop anyway
                if pages_grabbed >= max_pages_limit:
                    print("  [LIMIT] Reached max page limit.")
                    return extracted_text

        return extracted_text

    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# Walk through the directory structure
for root, dirs, files in os.walk(INPUT_DIR):
    for file in files:
        if file.endswith(".pdf"):
            company_name = os.path.basename(root)

            if company_name != "Nvdia":
                continue

            pdf_path = os.path.join(root, file)
            year = file.split("_")[-1].replace(".pdf", "") # naive year extractor

            print(f"Scanning {company_name} - {year}...")

            letter_text = extract_letter_from_pdf(pdf_path)

            if letter_text:
                # Save the extracted text
                output_filename = f"{company_name}_{year}_Letter.txt"
                output_path = os.path.join(OUTPUT_DIR, output_filename)

                with open(output_path, "w", encoding="utf-8") as f:
                    f.write(letter_text)
                print(f"  [SAVED] {output_filename}")
            else:
                print(f"  [MISSING] No letter pattern found in first 20 pages.")
# Out:
# Scanning Nvdia - 2012...
#   [START] Found start signature 'dear\s+fellow' on page 3
#   [STOP] Found end signature 'sincerely' on page 5
#   [SAVED] Nvdia_2012_Letter.txt
# Scanning Nvdia - 2011...
#   [START] Found start signature 'dear\s+fellow' on page 12
#   [STOP] Found end signature 'sincerely' on page 17
#   [SAVED] Nvdia_2011_Letter.txt
# Scanning Nvdia - 2010...
#   [MISSING] No letter pattern found in first 20 pages.
# Scanning Nvdia - 2019...
#   [START] Found start signature 'dear\s+nvidians' on page 12
#   [SAVED] Nvdia_2019_Letter.txt
# Scanning Nvdia - 2014...
#   [START] Found start signature 'dear\s+stakeholders' on page 12
#   [STOP] Found end signature 'sincerely' on page 14
#   [SAVED] Nvdia_2014_Letter.txt
# Scanning Nvdia - 2017...
#   [START] Found start signature 'dear\s+nvidians' on page 12
#   [SAVED] Nvdia_2017_Letter.txt
# Scanning Nvdia - 2018...
#   [START] Found start signature 'dear\s+nvidians' on page 12
#   [SAVED] Nvdia_2018_Letter.txt
# Scanning Nvdia - 2015...
#   [START] Found start signature 'dear\s+stakeholders' on page 12
#   [STOP] Found end signature 'sincerely' on page 14
#   [SAVED] Nvdia_2015_Letter.txt
# Scanning Nvdia - 2016...
#   [START] Found start signature 'dear\s+nvidians' on page 12
#   [SAVED] Nvdia_2016_Letter.txt
# Scanning Nvdia - 2013...
#   [START] Found start signature 'dear\s+fellow' on page 3
#   [STOP] Found end signature 'sincerely' on page 10
#   [SAVED] Nvdia_2013_Letter.txt
# Scanning Nvdia - 2022...
#   [START] Found start signature 'dear\s+nvidians' on page 14
#   [SAVED] Nvdia_2022_Letter.txt
# Scanning Nvdia - 2021...
#   [START] Found start signature 'dear\s+nvidians' on page 14
#   [SAVED] Nvdia_2021_Letter.txt
# Scanning Nvdia - 2020...
#   [START] Found start signature 'dear\s+nvidians' on page 7
#   [LIMIT] Reached max page limit.
#   [SAVED] Nvdia_2020_Letter.txt
# Scanning Nvdia - 2023...
#   [START] Found start signature 'dear\s+nvidians' on page 14
#   [SAVED] Nvdia_2023_Letter.txt

# %%
print(f"Checking files in {OUTPUT_DIR} for keywords 'China' or 'Chinese'...")

letters_china = []

for root, dirs, files in os.walk(OUTPUT_DIR):
    for file in files:
        file_path = os.path.join(root, file)
        try:
            with open(file_path, "r", encoding="utf-8") as f:
                content = f.read()

            # Find matches with context using regex
            matches = list(re.finditer(r'(china|chinese)', content, re.IGNORECASE))

            if matches:
                letters_china.append(file)
                print(f"\n[MATCH] {file}")
                # Print up to 3 snippets per file
                for i, m in enumerate(matches[:3]):
                    start = max(0, m.start() - 50)
                    end = min(len(content), m.end() + 50)
                    snippet = content[start:end].replace('\n', ' ')
                    print(f"   Snippet {i+1}: ...{snippet}...")
                if len(matches) > 3:
                    print(f"   ... and {len(matches) - 3} more matches.")

        except Exception as e:
            # print(f"[ERROR] Could not read {file}: {e}")
            pass

print(f"\nFound {len(letters_china)} files containing keywords.")

# Create the new directory
CHINA_DIR = "extracted_letters_china"
if not os.path.exists(CHINA_DIR):
    os.makedirs(CHINA_DIR)

print(f"\nCopying files to {CHINA_DIR}...")
for file in letters_china:
    src_path = os.path.join(OUTPUT_DIR, file)
    dst_path = os.path.join(CHINA_DIR, file)

    try:
        with open(src_path, "r", encoding="utf-8") as f_src:
            text_content = f_src.read()

        with open(dst_path, "w", encoding="utf-8") as f_dst:
            f_dst.write(text_content)
    except Exception as e:
        print(f"Error copying {file}: {e}")

print("Copying complete.")
# Out:
# Checking files in extracted_letters for keywords 'China' or 'Chinese'...
#
# [MATCH] Stellantis_2019_Letter.txt
#    Snippet 1: ...ep family, which also represented our  entry into China’s rapidly-growing New Energy Vehicle market.  We ...
#
# [MATCH] Nestle_2022_Letter.txt
#    Snippet 1: ...to shop in six months – with new sites  in Chile, China, India and Arlington, Virginia, in the  United St...
#    Snippet 2: ...ment. Through our regional R&D centers in Africa, China, India  and South-East Asia, we can innovate clos...
#    Snippet 3: ...rther refining for launch. Using these tools,  in China we launched Nescafé Dalgona coffee mixes  and Nes...
#    ... and 4 more matches.
#
# [MATCH] Blackrock_2010_Letter.txt
#    Snippet 1: ...o plague the U.S. housing market, home  prices in China soared amid worries of new asset bubbles in the f...
#    Snippet 2: ...tainty for markets.  in the standard of living in China have spurred  Debtor nations in the euro zone are...
#    Snippet 3: ...zone are facing tremen- demands for higher wages. China’s government has  dous political and social uphea...
#
# [MATCH] Blackrock_2014_Letter.txt
#    Snippet 1: ...experiencing headwinds; countries like  the U.S., China and India are experiencing the benefi  ts of  sti...
#    Snippet 2: ...ing economy” —  companies such as Uber, ZipCar or China’s Kuaidi.  Convenience is the obvious benefi t of...
#
# [MATCH] Pfizer_2012_Letter.txt
#    Snippet 1: ... the euro, the  Japanese yen, the U.K. pound, the Chinese renminbi, the Canadian dollar and approximately 1...
#
# [MATCH] Citigroup_2023_Letter.txt
#    Snippet 1: ...ssed with winding   down consumer operations   in China, Russia and   South Korea Progressed with   plans...
#    Snippet 2: ...lid progress winding down  consumer operations in China, Russia and South Korea. We  restarted the sales ...
#
# [MATCH] Nvdia_2012_Letter.txt
#    Snippet 1: ... set new standards for realism and game- play. In China, gamers keep 160,000+ icafes humming. The purpose...
#
# [MATCH] Citigroup_2018_Letter.txt
#    Snippet 1: ...by concerns about the  business cycle, trade with China and the  impact of Federal Reserve interest rate ...
#    Snippet 2: ...Committees Citi will sponsor   include Australia, Chinese Taipei,  Colombia, Costa Rica, Great Britain,  Ho...
#
# [MATCH] Volkswagen_2021_Letter.txt
#    Snippet 1: ...rs in the US  are new to the Volkswagen brand. In China, we delivered 93,000  electric  vehicles,  four  ...
#    Snippet 2: ... to  profit  and  positive  net  cash  flow.  In  China,  we  continue  to  be  very  profitable.  The  V...
#
# [MATCH] Intel_2011_Letter.txt
#    Snippet 1: ...he ﬁ rst time, total PC purchases were higher  in China than in any other country, followed by the U.S., ...
#    Snippet 2: ...he ﬁ rst time, total PC purchases were higher  in China than in any other country, followed by the U.S., ...
#
# [MATCH] BMW_2022_Letter.txt
#    Snippet 1: ...ion was also exacerbated by repeated lockdowns in China and  numerous bottlenecks affecting semiconductor...
#    Snippet 2: ...d the recurrent coronavirus -related lockdowns in China, we were pro- vided with up-to-date information o...
#    Snippet 3: ...events such  as the opening of the Lydia plant in China, which is fully geared to e-mobility production, ...
#    ... and 1 more matches.
#
# [MATCH] Toyota_2018_Letter.txt
#    Snippet 1: ...n Japan before  expanding it to North America and China. As the ﬁ rst  step toward connecting all vehicle...
#
# [MATCH] Benz_2021_Letter.txt
#    Snippet 1: ...inted until December 2024 Hubertus Troska Greater China Appointed until December 2025 Harald Wilhelm Fina...
#
# [MATCH] HSBC_2018_Letter.txt
#    Snippet 1: ...to  political pressure, and differences between   China and the US will likely continue to inform  sentim...
#    Snippet 2: ...should continue to support economic  development. China remains subject to domestic  and external pressur...
#    Snippet 3: ...further financial  liberalisation to form part of China’s response to  changing external conditions. This...
#    ... and 4 more matches.
#
# [MATCH] Volkswagen_2018_Letter.txt
#    Snippet 1: ...y regions  of  the  world.  This  also  includes  China,  where  the  economy  of  the  world.  This  als...
#    Snippet 2: ...  economy  of  the  world.  This  also  includes  China,  where  the  economy  dimmed considerably in the...
#    Snippet 3: ...e’s  largest  electric  production  network.  In  China,  too,  the  conversion  of  the  Anting  and  Fo...
#
# [MATCH] Nestle_2015_Letter.txt
#    Snippet 1: ...st few years as well as the company’s business in China.  Reflecting our belief in the importance of our ...
#
# [MATCH] Citigroup_2022_Letter.txt
#    Snippet 1: ...c inflationary pressures, persistent lockdowns in China  and the largest war on European soil since World...
#
# [MATCH] J&J_2011_Letter.txt
#    Snippet 1: ...t growth   in the BRIC (Brazil, Russia, India and China) markets   where we have introduced many innovati...
#    Snippet 2: ...arkets, with new innovation centers in India  and China, while continuing to support a number of training...
#
# [MATCH] P&G_2016_Letter.txt
#    Snippet 1: ...ers   vs. our best competition in North America,  China and Japan. And they are helping   drive results —...
#
# [MATCH] BMW_2011_Letter.txt
#    Snippet 1: ...ies. In 2012, we will open a new plant in Tiexi,  China. Future growth also exists in the BRIKT countries...
#    Snippet 2: ... the situation stabilising. Signs are emerging in China – currently the mainstay  of global economic grow...
#    Snippet 3: ...one continue to perform poorly. The situation in  China is being exacerbated by the fact that property  p...
#    ... and 1 more matches.
#
# [MATCH] Toyota_2017_Letter.txt
#    Snippet 1: ... Hybrid, equipped with hybrid units pro- duced in China, have been well received in the Chinese market. W...
#    Snippet 2: ...o- duced in China, have been well received in the Chinese market. We intend to  release plug-in hybrid vari...
#
# [MATCH] J&J_2013_Letter.txt
#    Snippet 1: ...Ltd, a leading baby care products company for the Chinese market and by launching LISTERINE® ADVANCED DEFEN...
#    Snippet 2: ...merging markets such as Brazil, Russia, India and China. • We created a unified business model in China. ...
#    Snippet 3: ...d China. • We created a unified business model in China. Johnson & Johnson was one of the first western c...
#    ... and 4 more matches.
#
# [MATCH] Nestle_2011_Letter.txt
#    Snippet 1: ...Nestlé Health Science, two major  partnerships in China, and significant investments in Russia,  India an...
#    Snippet 2: ...in local  culinary and nutritional traditions. In China, for example, we signed two partnerships,  acquir...
#    Snippet 3: ...would have had about CHF 4.5 billion  of sales in China in 2011. Both businesses have strong  brands that...
#    ... and 7 more matches.
#
# [MATCH] Nvdia_2011_Letter.txt
#    Snippet 1: ...uture, you’ll be able to hold up your phone to  a Chinese menu and see it instantly translated into  a chos...
#    Snippet 2: ...s helped  power the world’s fastest supercomputer—China’s  2.5 petaflop Tianhe-1A supercomputer—as well  ...
#
# [MATCH] Citigroup_2019_Letter.txt
#    Snippet 1: ...ral  economic storm clouds lifting. The U.S.  and China signed a Phase 1 trade deal,  the new United Stat...
#
# [MATCH] Jpmorgan_2023_Letter.txt
#    Snippet 1: ...d growing geopolitical tensions, importantly with China. Almost  all nations felt the effects last year o...
#
# [MATCH] HSBC_2017_Letter.txt
#    Snippet 1: ...and improving trade. Fears of a   hard landing in China have receded, and   markets across Asia look set ...
#    Snippet 2: ... We continued to expand our presence in mainland  China with the launch of new retail banking  products a...
#    Snippet 3: ..., the first securities joint venture in  mainland China to be majority-owned by an  international bank. T...
#    ... and 20 more matches.
#
# [MATCH] HSBC_2019_Letter.txt
#    Snippet 1: ...ank, albeit one closely  associated with mainland China, Hong Kong  and the UK. Each of these continues t...
#    Snippet 2: ...links with other key  partners, including the US, China and  south-east Asia. We look forward to working ...
#    Snippet 3: ...he agreement of a ‘phase one’ trade deal  between China and the US is a positive step,  but we remain cau...
#    ... and 5 more matches.
#
# [MATCH] HSBC_2022_Letter.txt
#    Snippet 1: ...hile further outbreaks in Hong Kong  and mainland China significantly  impacted economic growth, the Russ...
#    Snippet 2: ...lenges  and have different opportunities in 2023. China’s reopening and package of measures  to stabilise...
#    Snippet 3: ...me near-term  volatility. Our economists forecast China’s  GDP will grow 5% in 2023. The reopening of  th...
#    ... and 11 more matches.
#
# [MATCH] Volkswagen_2022_Letter.txt
#    Snippet 1: ...rs We  are  the  market  leader  in  Europe  and  China  and  aim  to  hold  this  position.  At  the  sa...
#    Snippet 2: ...portunity  for  the  Group  in  the  market.  In  China,  we  will  continue  to  invest  in  e-mobility ...
#    Snippet 3: ...sistance  systems and highly automated driving in China.  Another priority in the past year was our compa...
#    ... and 2 more matches.
#
# [MATCH] Jpmorgan_2020_Letter.txt
#    Snippet 1: ...g of 5-year cumulative net client asset flows26   China inbound funds AUM27 Global Funds AUM ($T)   Globa...
#    Snippet 2: ...m, Competitiveness and Leadership: Challenged by  China, COVID-19 and Our Own Competence 1.  Laying out t...
#
# [MATCH] Toyota_2014_Letter.txt
#    Snippet 1: ...rave reviews around the globe.  1921 in Shanghai, China, namely, “open your door, and look outside,” an a...
#
# [MATCH] Blackrock_2015_Letter.txt
#    Snippet 1: ... selling securities to meet  liquidity needs.  In China, the waning construction boom has left a lasting ...
#    Snippet 2: ...ountry will fuel future  growth. Sell-offs in the Chinese markets and inconsistent  policy responses have h...
#
# [MATCH] Goldman_2019_Letter.txt
#    Snippet 1: ... 10,000  Women’s 10th anniversary of operating in China and   the expansion of 10,000 Small Businesses in...
#
# [MATCH] Nestle_2018_Letter.txt
#    Snippet 1: ... by  stronger momentum in the United States   and China, as well as in infant nutrition.  – Total reporte...
#    Snippet 2: ...xamples included Nestlé  Skin Health and Yinlu in China. Innovating products and business models.  Rapid ...
#
# [MATCH] Jpmorgan_2016_Letter.txt
#    Snippet 1: ...next several years.  De-globalization, Mexico and China. Anti-globalization sentiment is growing in  part...
#    Snippet 2: ...with two of our key  trading partners: Mexico and China.  The trade deal with Mexico through NAFTA  is si...
#    Snippet 3: ...exico through NAFTA  is simpler than the one with China. (In full  disclosure, JPMorgan Chase is a major ...
#
# [MATCH] Jpmorgan_2018_Letter.txt
#    Snippet 1: ...o support them. The investments we are  making in China and in other emerging markets today will result i...
#
# [MATCH] BMW_2012_Letter.txt
#    Snippet 1: ...   reported on the Group’s business activities in China, in particular on the sales situation there, the ...
#    Snippet 2: ...: Tiexi is the most sustainable vehicle plant  in China today and one of the most advanced in the world. ...
#
# [MATCH] P&G_2010_Letter.txt
#    Snippet 1: ...fic face care regimen under the Gillette name in  China. In June, we introduced Gillette Fusion ProSeries...
#    Snippet 2: ...009. Crest Pro-Health is off to a strong start in China, helping  to drive Oral Care shipments in China u...
#    Snippet 3: ...n China, helping  to drive Oral Care shipments in China up high single digits in  the final quarter of th...
#
# [MATCH] Microsoft_2015_Letter.txt
#    Snippet 1: ...ltinational company to operate a public cloud  in China. Even as organizations transition to the cloud, w...
#
# [MATCH] Volkswagen_2020_Letter.txt
#    Snippet 1: ... We  continued  our  40-year  success  story  in  China,  primarily  with a view to achieving zero-emissi...
#    Snippet 2: ...r intention to become the largest shareholder in  Chinese  battery  maker  Gotion  by  acquiring  26%  of  ...
#    Snippet 3: ... Scania launched its first production facility in China. The  groundwork for enhanced efficiency in Germa...
#    ... and 1 more matches.
#
# [MATCH] Goldman_2017_Letter.txt
#    Snippet 1: ...h, boosted  by the strength of its exports, while China grew robustly, in part due to the  global recover...
#    Snippet 2: ...han double our average from 2009 to 2011. Lastly, China continues to represent a larger portion   of the ...
#    Snippet 3: ... percent of  the Fortune Global 500 companies are Chinese. In   2017, we were ranked first in equity and eq...
#    ... and 3 more matches.
#
# [MATCH] Nvdia_2020_Letter.txt
#    Snippet 1: ...d a rapidly  deteriorating trade environment with China.  Despite being knocked back on our heels at  the...
#
# [MATCH] HSBC_2021_Letter.txt
#    Snippet 1: ...out of HSBC  Personal Wealth Planning in mainland China,  and acquisitions in Singapore and India to  acc...
#    Snippet 2: ...s to   the different challenges they face.  After China’s strong recovery, growth slowed  in the second h...
#    Snippet 3: ... the second half of 2021. As a result, we  expect China’s government to take action to  ease monetary and...
#    ... and 8 more matches.
#
# [MATCH] Toyota_2010_Letter.txt
#    Snippet 1: ...for the  ・ Developing Products from the   Immense China Market   Customer’s Perspective   in India’s High...
#
# [MATCH] HSBC_2016_Letter.txt
#    Snippet 1: ...ance experience and a deep  knowledge of Asia and China. These attributes  were accumulated in a 25-year ...
#    Snippet 2: ... time, the US economy  looks robust and growth in China has held up   well, defying the concerns reflecte...
#    Snippet 3: ...balance growth in the UK, Hong Kong  and mainland China, and higher current account  and savings balances...
#    ... and 11 more matches.
#
# [MATCH] BMW_2020_Letter.txt
#    Snippet 1: ...Brilliance Automotive’s second battery  centre in China as well as the new communication concept for the ...
#    Snippet 2: ...int venture strategy and the  market situation in China.  In light of the coronavirus pandemic and the ac...
#
# [MATCH] Goldman_2013_Letter.txt
#    Snippet 1: ...e advanced recovery. Fears of a sharp slowdown in China receded somewhat   and the country’s new leadersh...
#    Snippet 2: ...n Sachs had in  Industrial and Commercial Bank of China Limited (ICBC), which was both strategic  and ﬁna...
#
# [MATCH] BMW_2013_Letter.txt
#    Snippet 1: ...he world’s major markets, particularly in the EU, China, USA and  Japan, both for vehicles powered by com...
#    Snippet 2: ...n particular  on the latest status of projects in China and on plans for building further production site...
#    Snippet 3: ...untries. In 2013, our two largest single markets, China and the US, accounted for around 20 and  19 %, re...
#
# [MATCH] Benz_2020_Letter.txt
#    Snippet 1: ...hus  achieved the ambitious Co2 limits in europe. China continues  to be our biggest market. With a twelv...
#    Snippet 2: ...markers: We will produce mercedes- Benz trucks in China in a few years’ time, enabling us to make  even b...
#
# [MATCH] HSBC_2015_Letter.txt
#    Snippet 1: ...ly licensed securities joint-venture  in mainland China is the culmination of more   than a decade of see...
#    Snippet 2: ...y   for HSBC to contribute to the development of  China’s capital markets. ‘ Our three major businesses g...
#    Snippet 3: ...ablish   a highly competitive platform to service China’s  international trade and investment flows as it...
#    ... and 8 more matches.
#
# [MATCH] P&G_2011_Letter.txt
#    Snippet 1: ...ng the BRIC countries (Brazil, Russia, India, and China) and successfully accelerated our historic growth...
#    Snippet 2: ...ories. In Russia and Mexico, we’re in the 20s. In China, Brazil and India, we’re in the mid-to-high teens...
#    Snippet 3: ...rate about $20 per person in Mexico. Our sales in China are only about $4 per person. Indonesia is just o...
#    ... and 5 more matches.
#
# [MATCH] BMW_2023_Letter.txt
#    Snippet 1: ... preview of the NEUE KLASSE. A talk by a renowned Chinese economics  expert on the state of the Chinese eco...
#    Snippet 2: ...ned Chinese economics  expert on the state of the Chinese economy in the wake of the coronavirus pandemic a...
#    Snippet 3: ...p  since 1999 and has headed up activities in the China region since 2018. In Jochen Goller,  we have app...
#    ... and 1 more matches.
#
# [MATCH] HSBC_2020_Letter.txt
#    Snippet 1: ... the impact of trade tensions  between the US and China, Brexit, low  interest rates and rapid technologi...
#    Snippet 2: ...he most impressive  economic recovery has been in China – still  the biggest driver of global growth – wh...
#    Snippet 3: ...he recent political agreement  between the EU and China on an investment  deal should, once ratified, bol...
#    ... and 2 more matches.
#
# [MATCH] Toyota_2021_Letter.txt
#    Snippet 1: ...rcent of its sales in Europe, North America, and  China by the same year, followed by BEVs accounting  We...
#
# [MATCH] Blackrock_2012_Letter.txt
#    Snippet 1: ...tates, slower growth and political  succession in China and turmoil in the Middle East. While US  equity ...
#    Snippet 2: ...ients on topics including  the US housing market, China’s evolving economic role and the  impact of the s...
#    Snippet 3: ...ng Wang joined the firm as Chairman of  BlackRock China. BlackRock’s first global brand initiative — our ...
#    ... and 1 more matches.
#
# [MATCH] SAP_2015_Letter.txt
#    Snippet 1: ...ran and the risk of lower  economic growth out of China.  Santos Annual Report 2015 / 1  --- Page 4 --- W...
#    Snippet 2: ...Asia,  and Vice President and  General Manager of China.  Previously held managerial  and staff positions...
#    Snippet 3: ...artner of Baird  Capital Partners Asia, based  in China, from 2007 to June  2012, and non-executive  Dire...
#
# [MATCH] P&G_2013_Letter.txt
#    Snippet 1: ..., most recently expanding   to Brazil, Mexico and China. Fusion   has grown global value share for  30 st...
#
# [MATCH] Citigroup_2010_Letter.txt
#    Snippet 1: ...ut return on equity as the impact of all the new  China and India alone, middle class households are expe...
#
# [MATCH] BMW_2015_Letter.txt
#    Snippet 1: ...s as well as the purchase of a leasing company in China. Furthermore,  the Board of Management reported o...
#    Snippet 2: ...o- nomic developments and business performance in China. Other subjects of discussion were progress in th...
#    Snippet 3: ...comprehensive  charging infrastructure in Europe, China and the USA. Consistent technology transfer from ...
#
# [MATCH] Intel_2014_Letter.txt
#    Snippet 1: ...mark agreements with Rockchip and Spreadtrum   in China give us new sources of innovation and partners wi...
#
# [MATCH] Citigroup_2016_Letter.txt
#    Snippet 1: ...d portfolio Citi announces it will sell  stake in China Guangfa Bank 4 14 Citi announces winners of  Smar...
#
# [MATCH] BMW_2018_Letter.txt
#    Snippet 1: ... target.  This figure only partially includes our China business, as is usual. The Group EBT margin of  1...
#    Snippet 2: ...ufacturer of automotive battery cells, CATL, from China, and with Northvolt in  a European consortium. ...
#
# [MATCH] Goldman_2015_Letter.txt
#    Snippet 1: ...As the year progressed, increasing concerns about China,  the first rate hike from the U.S. Federal Reser...
#    Snippet 2: ...g Afghanistan, Egypt, Rwanda, Brazil, India   and China — with business and management education,  mentor...
#    Snippet 3: ...ks  in 14 countries, enabling women from Kenya to China   to Laos to access capital and grow their busine...
#    ... and 3 more matches.
#
# [MATCH] Volkswagen_2023_Letter.txt
#    Snippet 1: ... Nutzfahrzeuge TRATON GROUP Audi Volkswagen Group China  Porsche Volkswagen Financial Services TRATON GRO...
#    Snippet 2: ... Financial Services TRATON GROUP Volkswagen Group China Volkswagen Finanzdienstleistungen C orporate G ov...
#    Snippet 3: ... with all regions contributing to this growth. In China, the Group’s largest  single  market,  we  expand...
#    ... and 11 more matches.
#
# [MATCH] P&G_2012_Letter.txt
#    Snippet 1: ...ﬁ t. They are disproportionately in the  U.S. and China, which are P&G’s ﬁ rst and second largest, most  ...
#
# [MATCH] Nestle_2013_Letter.txt
#    Snippet 1: ...t of Amway  Corporation responsible   for Greater China and  Southeast Asia Region. Term expires 2016 (1)...
#    Snippet 2: ... term. We aim to create shared value. Japan 2.18% China 2.48% France 2.48%  Luxembourg 2.66% Belgium 2.86...
#    Snippet 3: ...0% 0% Switzerland 34.49% USA 26.77% Others Japan  China France Luxembourg Belgium Germany Norway  United ...
#
# [MATCH] Nestle_2016_Letter.txt
#    Snippet 1: ...he external image of the company and travelled to China in order to  better understand the dynamics of ou...
#
# [MATCH] Nestle_2012_Letter.txt
#    Snippet 1: ...ill get  access to one of the leading traditional Chinese medicine  libraries. Nestlé Nutrition’s global le...
#    Snippet 2: ...lar, it enhances our position in that category in China.  China would now be Nestlé’s second biggest mark...
#    Snippet 3: ...enhances our position in that category in China.  China would now be Nestlé’s second biggest market,  wit...
#    ... and 5 more matches.
#
# [MATCH] IBM_2010_Letter.txt
#    Snippet 1: ...n the largest of these emerging markets,  such as China, India and Brazil, IBM is broadening   its well-e...
#
# [MATCH] Microsoft_2014_Letter.txt
#    Snippet 1: ...enter footprint into Australia, Brazil, Japan and China. We brought industry-leading in-memory technology...
#
# [MATCH] Nestle_2023_Letter.txt
#    Snippet 1: ... Additionally, we launched the Nestlé N3 range in China  that helps people maintain their overall health ...
#    Snippet 2: ... 2023,  in a range of powdered dairy products  in China, tailored to meet the dietary  needs of local con...
#
# [MATCH] Nestle_2017_Letter.txt
#    Snippet 1: ...sumer trends, our business  in Zone AOA including China, as well as our  Nestlé Health Science and Nestlé...
#
# [MATCH] BMW_2014_Letter.txt
#    Snippet 1: ... extension of the cooperation  agreement with the Chinese joint venture partner Brilliance, the cooperation...
#    Snippet 2: ...rilliance  Automotive Ltd. (BBA) joint venture in China. Representatives of the managements of BBA and th...
#    Snippet 3: ...o us on sales volume trends and the car market in China in general as well as plans  for additionally inc...
#    ... and 3 more matches.
#
# [MATCH] Citigroup_2017_Letter.txt
#    Snippet 1: ...warded Type-A Bond  Settlement Agent license   in China 3  --- Page 6 --- Letter To Shareholders We know ...
#
# [MATCH] Goldman_2014_Letter.txt
#    Snippet 1: ...strained. And in Asia, conditions slowed in both  China and Japan. Different countries are clearly at dif...
#    Snippet 2: ...stment   in the Industrial and Commercial Bank of China. We also   sold our hedge fund administration bus...
#    Snippet 3: ...6  Goldman Sachs 2014 Annual Report We hosted the China-U.S. CEO Bilateral Investment   Dialogue in Beiji...
#    ... and 3 more matches.
#
# [MATCH] Volkswagen_2019_Letter.txt
#    Snippet 1: ...rmed  exceedingly  well  around  the  world.  In  China,  we  lifted  our  market  share  in  a  declinin...
#
# Found 77 files containing keywords.
#
# Copying files to extracted_letters_china...
# Copying complete.

# %%
data_rows = []

for filename in letters_china:
    # Expected format: "CompanyName_Year_Letter.txt"
    # using rsplit to safely handle names with underscores if any (though logic suggests single word or simple names)
    # based on previous logic: company_name = filename.split("_")[0]
    parts = filename.split("_")

    # Handle cases where company name might contain underscores?
    try:
        base = filename.replace("_Letter.txt", "")
        # finding the last underscore to separate company and year
        last_underscore_index = base.rfind("_")
        if last_underscore_index == -1:
            continue

        company_name = base[:last_underscore_index]
        year = base[last_underscore_index+1:]

        # Get data from dictionary
        if company_name in d_companies:
            company_data = d_companies[company_name]
            slug = get_slug(company_name, company_data)

            if slug:
                # Reconstruct URL logic
                clean_slug = slug.replace("NASDAQ_", "").replace("NYSE_", "").replace("OTC_", "")
                first_letter = clean_slug[0].lower()
                pdf_filename = f"{slug}_{year}.pdf"
                url = f"https://www.annualreports.com/HostedData/AnnualReportArchive/{first_letter}/{pdf_filename}"

                # Read the text content
                file_path = os.path.join(CHINA_DIR, filename)
                with open(file_path, "r", encoding="utf-8") as f:
                    letter_text = f.read()

                data_rows.append({
                    "Company Name": company_name,
                    "Year": year,
                    "url": url,
                    "Letter Text": letter_text
                })
        else:
            print(f"Warning: {company_name} not found in d_companies")

    except Exception as e:
        print(f"Error parsing {filename}: {e}")

df = pd.DataFrame(data_rows)
display(df)
# Out:
#    Company Name  Year                                                url  \
# 0    Stellantis  2019  https://www.annualreports.com/HostedData/Annua...
# 1        Nestle  2022  https://www.annualreports.com/HostedData/Annua...
# 2     Blackrock  2010  https://www.annualreports.com/HostedData/Annua...
# 3     Blackrock  2014  https://www.annualreports.com/HostedData/Annua...
# 4        Pfizer  2012  https://www.annualreports.com/HostedData/Annua...
# ..          ...   ...                                                ...
# 72       Nestle  2017  https://www.annualreports.com/HostedData/Annua...
# 73          BMW  2014  https://www.annualreports.com/HostedData/Annua...
# 74    Citigroup  2017  https://www.annualreports.com/HostedData/Annua...
# 75      Goldman  2014  https://www.annualreports.com/HostedData/Annua...
# 76   Volkswagen  2019  https://www.annualreports.com/HostedData/Annua...
#
#                                           Letter Text
# 0   \n--- Page 9 ---\n7 \nMessage from the Chairma...
# 1   \n--- Page 6 ---\nStaying the course \nDear fe...
# 2   \n--- Page 6 ---\nMy Fellow Shareholders\nApri...
# 3   \n--- Page 17 ---\nl auRence d. fInk   Chairma...
# 4   \n--- Page 8 ---\nFinancial Review\nPfizer Inc...
# ..                                                ...
# 72  \n--- Page 6 ---\nDear fellow shareholders,\nF...
# 73  \n--- Page 7 ---\n7   REPORT OF THE SUPERVISOR...
# 74  \n--- Page 4 ---\nLetter To Shareholders\n7\n1...
# 75  \n--- Page 2 ---\nThe Goldman Sachs Business P...
# 76  \n--- Page 10 ---\n8 \nLetter to our Sharehold...
#
# [77 rows x 4 columns]

# %%
client = genai.Client(api_key=userdata.get('GEMINI_API_KEY'))
MODEL_NAME = "gemini-2.5-flash"

# %%
BATCH_SIZE = 5
analysis_results = {} # Dictionary to store results by index

if df.empty:
    print("Warning: DataFrame is empty.")
else:
    total_batches = (len(df) + BATCH_SIZE - 1) // BATCH_SIZE
    print(f"Processing {len(df)} letters in {total_batches} batches (Batch Size: {BATCH_SIZE})...")

    # Iterate through the DataFrame in chunks
    for batch_idx, i in enumerate(range(0, len(df), BATCH_SIZE)):
        batch = df.iloc[i : i + BATCH_SIZE]

        # Construct a combined prompt for the batch
        prompt_text = """
        You are an expert financial analyst. Analyze the following shareholder letters regarding their discussion of China.

        For EACH letter provided below (identified by LETTER_ID), perform the following:
        1. Identify the author's name and role.
        2. Summarize the discussion regarding "China".
        3. Determine the sentiment towards China (optimistic growth, cautious engagement, hedging, de-risking, uncertainty management, etc, etc).

        Output strict JSON. Return a list of objects. Each object MUST include the 'letter_id' (integer) provided in the header.
        Format:
        [
            {"letter_id": <int>, "author_name": "...", "author_role": "...", "china_summary": "...", "china_sentiment": "..."},
            ...
        ]
        """

        # Append text of each letter in the batch
        for idx, row in batch.iterrows():
            # Truncate text to ensure we fit multiple letters in context (approx 20k chars per letter is safe for Flash)
            safe_text = row['Letter Text'][:20000]
            prompt_text += f"\n\n=== START LETTER_ID {idx} ({row['Company Name']} {row['Year']}) ===\n{safe_text}\n=== END LETTER_ID {idx} ==="

        # Retry logic for the batch
        max_retries = 3
        for attempt in range(max_retries):
            try:
                response = client.models.generate_content(
                    model=MODEL_NAME,
                    contents=[types.Content(parts=[types.Part.from_text(text=prompt_text)])],
                    config=types.GenerateContentConfig(response_mime_type="application/json")
                )

                # Parse response
                batch_json = json.loads(response.text)

                # Store results mapped by letter_id
                if isinstance(batch_json, list):
                    for item in batch_json:
                        lid = item.get('letter_id')
                        if lid is not None:
                            analysis_results[lid] = item

                print(f"Batch {batch_idx+1}/{total_batches} completed.")
                time.sleep(2) # Respect rate limits
                break
            except Exception as e:
                print(f"Batch {batch_idx+1} attempt {attempt+1} failed: {e}")
                time.sleep(5)

    # Merge results back into the DataFrame
    if analysis_results:
        # Create DataFrame from results dict (keys are indices)
        results_df = pd.DataFrame.from_dict(analysis_results, orient='index')

        # Select only the columns we want to add
        cols_to_add = ['author_name', 'author_role', 'china_summary', 'china_sentiment']

        # Ensure columns exist in results (in case of empty results or partial failures)
        for col in cols_to_add:
            if col not in results_df.columns:
                results_df[col] = None

        # Join with original DataFrame
        df_final = df.join(results_df[cols_to_add])
        display(df_final.head())
    else:
        print("No results generated.")
# Out:
# Processing 77 letters in 16 batches (Batch Size: 5)...
# Batch 1/16 completed.
# Batch 2/16 completed.
# Batch 3/16 completed.
# Batch 4/16 completed.
# Batch 5/16 completed.
# Batch 6/16 completed.
# Batch 7/16 completed.
# Batch 8/16 completed.
# Batch 9/16 completed.
# Batch 10/16 completed.
# Batch 11/16 completed.
# Batch 12/16 completed.
# Batch 13/16 completed.
# Batch 14 attempt 1 failed: Expecting ',' delimiter: line 6 column 60 (char 210)
# Batch 14/16 completed.
# Batch 15/16 completed.
# Batch 16/16 completed.
#   Company Name  Year                                                url  \
# 0   Stellantis  2019  https://www.annualreports.com/HostedData/Annua...
# 1       Nestle  2022  https://www.annualreports.com/HostedData/Annua...
# 2    Blackrock  2010  https://www.annualreports.com/HostedData/Annua...
# 3    Blackrock  2014  https://www.annualreports.com/HostedData/Annua...
# 4       Pfizer  2012  https://www.annualreports.com/HostedData/Annua...
#
#                                          Letter Text  \
# 0  \n--- Page 9 ---\n7 \nMessage from the Chairma...
# 1  \n--- Page 6 ---\nStaying the course \nDear fe...
# 2  \n--- Page 6 ---\nMy Fellow Shareholders\nApri...
# 3  \n--- Page 17 ---\nl auRence d. fInk   Chairma...
# 4  \n--- Page 8 ---\nFinancial Review\nPfizer Inc...
#
#                                          author_name  \
# 0                           John Elkann; Mike Manley
# 1                     Paul Bulcke; U. Mark Schneider
# 2                                   Laurence D. Fink
# 3                                   Laurence D. Fink
# 4  Not explicitly stated (Pfizer Inc. and Subsidi...
#
#                             author_role  \
# 0     Chairman; Chief Executive Officer
# 1     Chairman; Chief Executive Officer
# 2    Chairman & Chief Executive Officer
# 3  Chairman and Chief Executive Officer
# 4                    Company Management
#
#                                        china_summary  \
# 0  Fiat Chrysler Automobiles (FCA), now Stellanti...
# 1  The letter does not specifically discuss China...
# 2  BlackRock observed soaring home prices in Chin...
# 3  BlackRock cited China's Kuaidi as an example o...
# 4  Pfizer stated that it operates in multiple for...
#
#                                      china_sentiment
# 0  Cautious engagement. While acknowledging 'cont...
# 1  Not explicitly stated. The general sentiment t...
# 2  Cautious engagement. While recognizing China a...
# 3  Optimistic engagement. China is presented in a...
# 4  Neutral/operational. The discussion of China i...

# %%
df_final["source"] = "Shareholder Letter"

# %%
df_final.to_csv("extracted_letters_china_gemini.csv", index=False)
